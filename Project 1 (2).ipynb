# %%
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\ASUS\Downloads\DataCoSupplyChainDataset.csv')

# %%
data
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
data1=pd.DataFrame(data)

# %%
data1.head(10)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
# 5  TRANSFER                         6                              4
# 6     DEBIT                         2                              1
# 7  TRANSFER                         2                              1
# 8      CASH                         3                              2
# 9      CASH                         2                              1
#
#    Benefit per order  Sales per customer    Delivery Status  \
# 0          91.250000          314.640015   Advance shipping
# 1        -249.089996          311.359985      Late delivery
# ...

# %%
#display all the columns name
data1.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
#datatype of all the columns
data1.dtypes
# Out:
# Type                              object
# Days for shipping (real)           int64
# Days for shipment (scheduled)      int64
# Benefit per order                float64
# Sales per customer               float64
# Delivery Status                   object
# Late_delivery_risk                 int64
# Category Id                        int64
# Category Name                     object
# Customer City                     object
# Customer Country                  object
# Customer Email                    object
# Customer Fname                    object
# Customer Id                        int64
# Customer Lname                    object
# Customer Password                 object
# Customer Segment                  object
# Customer State                    object
# Customer Street                   object
# Customer Zipcode                 float64
# Department Id                      int64
# Department Name                   object
# Latitude                         float64
# ...

# %%
#display no of rows given in data
data.count()
# Out:
# Type                             180519
# Days for shipping (real)         180519
# Days for shipment (scheduled)    180519
# Benefit per order                180519
# Sales per customer               180519
# Delivery Status                  180519
# Late_delivery_risk               180519
# Category Id                      180519
# Category Name                    180519
# Customer City                    180519
# Customer Country                 180519
# Customer Email                   180519
# Customer Fname                   180519
# Customer Id                      180519
# Customer Lname                   180511
# Customer Password                180519
# Customer Segment                 180519
# Customer State                   180519
# Customer Street                  180519
# Customer Zipcode                 180516
# Department Id                    180519
# Department Name                  180519
# Latitude                         180519
# ...

# %%
data1.shape[1]
# Out:
# 53

# %%
#find empty values of all coloumns
null_data=data.isnull()

# %%
null_data.head(5)
# Out:
#     Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0  False                     False                          False
# 1  False                     False                          False
# 2  False                     False                          False
# 3  False                     False                          False
# 4  False                     False                          False
#
#    Benefit per order  Sales per customer  Delivery Status  Late_delivery_risk  \
# 0              False               False            False               False
# 1              False               False            False               False
# 2              False               False            False               False
# 3              False               False            False               False
# 4              False               False            False               False
#
#    Category Id  Category Name  Customer City  ...  Order Zipcode  \
# ...

# %%
#adding two customer name
cust_fullname=data1['Customer Fname']+' '+data1['Customer Lname']

# %%
cust_fullname.head(10)
# Out:
# 0       Cally Holloway
# 1           Irene Luna
# 2    Gillian Maldonado
# 3            Tana Tate
# 4       Orli Hendricks
# 5     Kimberly Flowers
# 6    Constance Terrell
# 7        Erica Stevens
# 8        Nichole Olsen
# 9       Oprah Delacruz
# dtype: object

# %%
data1['Customer name']=cust_fullname

# %%
data1.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Customer Zipcode',
#        'Department Id', 'Department Name', 'Latitude', 'Longitude', 'Market',
#        'Order City', 'Order Country', 'Order Customer Id',
#        'order date (DateOrders)', 'Order Id', 'Order Item Cardprod Id',
#        'Order Item Discount', 'Order Item Discount Rate', 'Order Item Id',
#        'Order Item Product Price', 'Order Item Profit Ratio',
#        'Order Item Quantity', 'Sales', 'Order Item Total',
#        'Order Profit Per Order', 'Order Region', 'Order State', 'Order Status',
# ...

# %%
data1
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
data.drop(columns =["Customer Fname"], inplace = True)#dropping the columns as new column 'Customer name ' added

# %%
data.drop(columns =["Customer Lname"], inplace = True)

# %%
data.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Id',
#        'Customer Password', 'Customer Segment', 'Customer State',
#        'Customer Zipcode', 'Department Id', 'Department Name', 'Latitude',
#        'Longitude', 'Market', 'Order City', 'Order Country',
#        'Order Customer Id', 'order date (DateOrders)', 'Order Id',
#        'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Sales',
#        'Order Item Total', 'Order Profit Per Order', 'Order Region',
#        'Order State', 'Order Status', 'Order Zipcode', 'Product Card Id',
#        'Product Category Id', 'Product Description', 'Product Image',
# ...

# %%
#6.split the column customer street and get customer street code and customer street name
n = data1["Customer Street"].str.split(" ", n = 1, expand = True)

# %%
n
# Out:
#            0                      1
# 0       5365    Noble Nectar Island
# 1       2679            Rustic Loop
# 2       8510        Round Bear Gate
# 3       3200             Amber Bend
# 4       8671    Iron Anchor Corners
# ...      ...                    ...
# 180514  1322            Broad Glade
# 180515  7330       Broad Apple Moor
# 180516    97        Burning Landing
# 180517  2585  Silent Autumn Landing
# 180518   697          Little Meadow
#
# [180519 rows x 2 columns]

# %%
data["Customer Street Code"]= n[0]#new column addition

# %%
data["Customer Street Name"]= n[1]

# %%
data.drop(columns =["Customer Street"], inplace = True)

# %%
data.head(5)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %%
#7.Which is shipping prefferd most in each country
Shipping_details=data1.groupby(['Order Country','Shipping Mode'])

# %%
Shipping_details.size().nlargest(50)
# Out:
# Order Country         Shipping Mode
# Estados Unidos        Standard Class    14676
# M�xico                Standard Class     7835
# Francia               Standard Class     7684
# Alemania              Standard Class     5691
# Australia             Standard Class     5085
# Estados Unidos        Second Class       4939
# Brasil                Standard Class     4877
# Reino Unido           Standard Class     4391
# Estados Unidos        First Class        3824
# China                 Standard Class     3501
# Italia                Standard Class     3081
# India                 Standard Class     2764
# Francia               Second Class       2714
# M�xico                Second Class       2705
# Indonesia             Standard Class     2445
# Honduras              Standard Class     2336
# Espa�a                Standard Class     2267
# El Salvador           Standard Class     2258
# Rep�blica Dominicana  Standard Class     2169
# Cuba                  Standard Class     2164
# ...

# %%
#8.which product having highest benefit order
data.groupby('Category Name').agg({'Benefit per order':'max'})['Benefit per order'].nlargest(1)
# Out:
# Category Name
# Strength Training    911.799988
# Name: Benefit per order, dtype: float64

# %%
data.groupby('Category Name').agg({'Benefit per order':'min'}).sort_values(by='Benefit per order',ascending=False).iloc[0:5]
# Out:
#                Benefit per order
# Category Name
# CDs                   -23.610001
# Toys                  -25.969999
# Books                 -76.150002
# Video Games          -104.110001
# Baby                 -138.779999

# %%
#9.Which city has highest customer
Customer_details=data1.groupby(['Customer City'])

# %%
for name,Group in Customer_details :
    print('\nGroup')
    print(name)
# Out:
# Group
# Aguadilla
#
# Group
# Alameda
#
# Group
# Albany
#
# Group
# Albuquerque
#
# Group
# Algonquin
#
# Group
# Alhambra
#
# Group
# Allentown
#
# Group
# Alpharetta
#
# Group
# Amarillo
#
# Group
# Anaheim
#
# Group
# Ann Arbor
#
# Group
# Annandale
#
# Group
# Annapolis
#
# Group
# Antioch
#
# Group
# Apex
#
# Group
# Apopka
#
# Group
# Arecibo
#
# Group
# Arlington
#
# Group
# Arlington Heights
#
# Group
# Asheboro
#
# Group
# Astoria
#
# Group
# Atlanta
#
# Group
# Augusta
#
# Group
# Aurora
#
# Group
# Austin
#
# Group
# Azusa
#
# Group
# Bakersfield
#
# Group
# Baldwin Park
#
# Group
# Ballwin
#
# Group
# Baltimore
#
# Group
# Bartlett
#
# Group
# Bay Shore
#
# Group
# Bayamon
#
# Group
# Bayonne
#
# Group
# Baytown
#
# Group
# Beaverton
#
# Group
# Bell Gardens
#
# Group
# Bellflower
#
# Group
# Bellingham
#
# Group
# Beloit
#
# Group
# Bend
#
# Group
# Bensalem
#
# Group
# Berwyn
#
# Group
# Billings
#
# Group
# Birmingham
#
# Group
# Bismarck
#
# Group
# Blacksburg
#
# ...

# %%
Customer_details['Customer Id'].size().nlargest(1)
# Out:
# Customer City
# Caguas    66770
# Name: Customer Id, dtype: int64

# %%
#10.Order date and Shipping date convert into single format
data['order date (DateOrders)']=pd.to_datetime(data['order date (DateOrders)'])
data['shipping date (DateOrders)']=pd.to_datetime(data['shipping date (DateOrders)'])

# %%
data['order date (DateOrders)']
# Out:
# 0        2018-01-31 22:56:00
# 1        2018-01-13 12:27:00
# 2        2018-01-13 12:06:00
# 3        2018-01-13 11:45:00
# 4        2018-01-13 11:24:00
#                  ...
# 180514   2016-01-16 03:40:00
# 180515   2016-01-16 01:34:00
# 180516   2016-01-15 21:00:00
# 180517   2016-01-15 20:18:00
# 180518   2016-01-15 18:54:00
# Name: order date (DateOrders), Length: 180519, dtype: datetime64[ns]

# %%
#11.list out no. pending order from city w.r.t INDIA
data[('Order City')][(data['Order Status']=='PENDING')& (data['Order Country']=='India' )]
# Out:
# 1             Bikaner
# 21           Jabalpur
# 45          Bangalore
# 46          Bangalore
# 382              Pune
#              ...
# 180142    Bhubaneswar
# 180164           Agra
# 180248          Dewas
# 180331          Ajmer
# 180405          Patna
# Name: Order City, Length: 537, dtype: object

# %%
#12.In which city highest fraud happend
data[('Order City')][(data['Order Status']=='SUSPECTED_FRAUD')].value_counts().head(50)
# Out:
# Managua           70
# San Francisco     67
# Santo Domingo     48
# New York City     45
# Mexico City       40
# London            33
# Philadelphia      32
# Yakarta           32
# Bangkok           30
# San Salvador      26
# Los Angeles       25
# Zapopan           24
# Chicago           24
# Berl�n            24
# Seattle           24
# Barcelona         23
# Wollongong        23
# Cairo             23
# Toulouse          22
# Sydney            22
# Villa Nueva       22
# Houston           22
# Viena             21
# Tegucigalpa       21
# Melbourne         21
# Manila            21
# San Pedro Sula    20
# Brisbane          19
# Lagos             18
# Dubl�n            18
# Ju�rez            17
# M�rida            17
# S�o Paulo         17
# Bogot�            17
# Milan             17
# Rome              17
# Tijuana           16
# Valencia          16
# Canberra          16
# Panama City       15
# Birmingham        15
# Camag�ey          14
# Izmir             14
# ...

# %%
#13.Which product has maximum discount
data['Product Name'][data['Order Item Discount']==data['Order Item Discount'].max()]
# Out:
# 12606    SOLE E35 Elliptical
# Name: Product Name, dtype: object

# %%
#14.Which year had the minimum sales for nike product
data[(data['Product Name'].str.contains('Nike'))]
# Out:
#                              Type  Days for shipping (real)  \
# order date (DateOrders)
# 2016-03-30 04:37:00       PAYMENT                         6
# 2016-11-28 01:18:00       PAYMENT                         3
# 2016-12-31 15:47:00       PAYMENT                         5
# 2015-10-25 06:24:00       PAYMENT                         6
# 2016-10-04 22:55:00       PAYMENT                         2
# ...                           ...                       ...
# 2017-03-31 01:39:00      TRANSFER                         5
# 2017-02-10 06:27:00      TRANSFER                         2
# 2017-06-13 02:57:00      TRANSFER                         3
# 2015-04-14 05:59:00      TRANSFER                         5
# 2015-01-18 11:21:00      TRANSFER                         4
#
#                          Days for shipment (scheduled)  Benefit per order  \
# order date (DateOrders)
# 2016-03-30 04:37:00                                  2          33.599998
# ...

# %%
data[(data['Product Name'].str.contains('Nike'))].valcounts()
# Out:
# Type                                                                          CASH
# Days for shipping (real)                                                         0
# Days for shipment (scheduled)                                                    0
# Benefit per order                                                     -1374.859985
# Sales per customer                                                            16.5
# Delivery Status                                                   Advance shipping
# Late_delivery_risk                                                               0
# Category Id                                                                      2
# Category Name                                                      As Seen on  TV!
# Customer City                                                            Aguadilla
# Customer Country                                                           EE. UU.
# ...

# %%
data
# Out:
#                              Type  Days for shipping (real)  \
# order date (DateOrders)
# 2018-01-31 22:56:00         DEBIT                         3
# 2018-01-13 12:27:00      TRANSFER                         5
# 2018-01-13 12:06:00          CASH                         4
# 2018-01-13 11:45:00         DEBIT                         3
# 2018-01-13 11:24:00       PAYMENT                         2
# ...                           ...                       ...
# 2016-01-16 03:40:00          CASH                         4
# 2016-01-16 01:34:00         DEBIT                         3
# 2016-01-15 21:00:00      TRANSFER                         5
# 2016-01-15 20:18:00       PAYMENT                         3
# 2016-01-15 18:54:00       PAYMENT                         4
#
#                          Days for shipment (scheduled)  Benefit per order  \
# order date (DateOrders)
# 2018-01-31 22:56:00                                  4          91.250000
# ...

# %%
for date,nike in y:
    print('\nGroup')
    print(date)
    print(nike)
# Out:
# Group
# 2015
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 54       PAYMENT                         6                              2
# 63       PAYMENT                         3                              2
# 66       PAYMENT                         4                              2
# 68       PAYMENT                         3                              2
# 73       PAYMENT                         6                              2
# ...          ...                       ...                            ...
# 179617  TRANSFER                         5                              4
# 179618  TRANSFER                         6                              4
# 179619  TRANSFER                         2                              4
# 179620  TRANSFER                         5                              4
# 179630  TRANSFER                         2                              4
#
# ...

# %%
y['order date (DateOrders)'].nlargest()
# Out:
# order date (DateOrders)
# 2015                     14194    2015-12-31 23:39:00
#                          14252    2015-12-31 23:39:00
#                          14807    2015-12-31 23:39:00
#                          51548    2015-12-31 23:39:00
#                          14835    2015-12-31 22:57:00
# 2016                     171256   2016-12-31 23:51:00
#                          171522   2016-12-31 23:51:00
#                          171813   2016-12-31 23:51:00
#                          172115   2016-12-31 23:51:00
#                          93987    2016-12-31 23:30:00
# 2017                     110367   2017-12-31 23:52:00
#                          42481    2017-12-31 23:31:00
#                          29048    2017-12-31 23:10:00
#                          124219   2017-12-31 22:49:00
#                          94361    2017-12-31 22:28:00
# 2018                     17863    2018-01-31 23:38:00
#                          52147    2018-01-31 23:17:00
# ...
